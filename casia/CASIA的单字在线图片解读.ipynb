# %%
import sys
sys.path.append('../utils')

from casia_image import POT
import zipfile

import os
root = 'E:/OCR/CASIA/data'  # CASI 数据集所在根目录

image_s1 = [f'{root}/{name}' for name in os.listdir(root) if 'pot' in name] # POT 图片的源文件
image_s1
# Out:
# ['E:/OCR/CASIA/data/OLHWDB1.0test_pot.zip',
#  'E:/OCR/CASIA/data/OLHWDB1.0train_pot.zip',
#  'E:/OCR/CASIA/data/OLHWDB1.1trn_pot.zip',
#  'E:/OCR/CASIA/data/OLHWDB1.1tst_pot.zip']

# %%
Z = zipfile.ZipFile('E:/OCR/CASIA/data/OLHWDB1.1trn_pot.zip')
Z.namelist()
# Out:
# ['1225-c.pot',
#  '1226-c.pot',
#  '1227-c.pot',
#  '1228-c.pot',
#  '1229-c.pot',
#  '1230-c.pot',
#  '1231-c.pot',
#  '1232-c.pot',
#  '1233-c.pot',
#  '1234-c.pot',
#  '1235-c.pot',
#  '1236-c.pot',
#  '1237-c.pot',
#  '1238-c.pot',
#  '1239-c.pot',
#  '1240-c.pot',
#  '1001-c.pot',
#  '1002-c.pot',
#  '1003-c.pot',
#  '1004-c.pot',
#  '1005-c.pot',
#  '1006-c.pot',
#  '1007-c.pot',
#  '1008-c.pot',
#  '1009-c.pot',
#  '1010-c.pot',
#  '1011-c.pot',
#  '1012-c.pot',
#  '1013-c.pot',
#  '1014-c.pot',
#  '1015-c.pot',
#  '1016-c.pot',
#  '1017-c.pot',
#  '1018-c.pot',
#  '1019-c.pot',
#  '1020-c.pot',
#  '1021-c.pot',
#  '1022-c.pot',
#  '1023-c.pot',
#  '1024-c.pot',
#  '1025-c.pot',
#  '1026-c.pot',
#  '1027-c.pot',
#  '1028-c.pot',
#  '1029-c.pot',
#  '1030-c.pot',
#  '1031-c.pot',
#  '1032-c.pot',
#  '1033-c.pot',
#  '1034-c.pot',
#  '1035-c.pot',
#  '1036-c.pot',
#  '1037-c.pot',
#  '1038-c.pot',
#  '1039-c.pot',
#  '1040-c.pot',
#  '1041-c.pot',
#  '1042-c.pot',
# ...

# %%
ss = 0
Z = zipfile.ZipFile('E:/OCR/CASIA/data/OLHWDB1.1trn_pot.zip')
for set_name in Z.namelist():
    pot = POT(Z, set_name)
    for tags, sizes in pot:
        ...
    ss += len(tags.keys())
# Out:
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# 解码结束！
# ...

# %%
ss == 898573
# Out:
# True

# %% [markdown]
# `gb18030` 是 `gbk` 或者 `gb2312` 的超集：

# %%
'┬'.encode('gb18030').decode('gbk'), '┬'.encode('gb18030').decode('gb2312')

# %% [markdown]
# `big5` 与 `big5hkscs` 是繁体字的编码方式：

# %%
'┬'.encode('gb18030').decode('big5'), '┬'.encode('gb18030').decode('big5hkscs')

# %%
'\ue7ae'.encode('gb18030').decode('big5')

# %% [markdown]
# ## 可视化

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
tag_code = '墙'
for i in tags[0][tag_code]:
    x, y = np.array(tags[0][tag_code][i]).T
    plt.plot(x, y)
plt.show()

# %%
tags[9]

# %%
from pathlib import Path

# %%
name = 'E:/OCR/CASIA/data/OLHWDB1.1trn_pot.zip'

# %%
# Out:
# 'pot'

# %%
# Out:
# 34
